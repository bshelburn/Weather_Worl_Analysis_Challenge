# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# %%
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
coordinates = list (lat_lng)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 751

# %%
# API key
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f8d7ed020ef7b067730ae11ad58fadc2

# %%
city_data = []

print('Begin Data Retrieval')
print('-' * 10)


record_count = 1
set_count = 1
for index, city in enumerate(cities):
    

    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        

    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        city_data.append(
        {
            'City': city,
            'Country': city_country,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Current Description': city_weather_description,
            
        })
    except:
        print('City not found. Skip')
        pass

print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Begin Data Retrieval
# ----------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | orzhytsya
# Processing Record 6 of Set 1 | cody
# Processing Record 7 of Set 1 | jasper
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | juba
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | luderitz
# Processing Record 15 of Set 1 | matagami
# Processing Record 16 of Set 1 | batagay-alyta
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | georgiyevka
# Processing Record 22 of Set 1 | lompoc
# Processing Record 23 of Set 1 | artigas
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skip
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | beringovskiy
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | picayune
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | amderma
# City not found. Skip
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | atar
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | nayoro
# Processing Record 36 of Set 1 | malaryta
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | hambantota
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | goderich
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | mazarron
# Processing Record 44 of Set 1 | areka
# Processing Record 45 of Set 1 | coquimbo
# Processing Record 46 of Set 1 | marcona
# City not found. Skip
# Processing Record 47 of Set 1 | geilo
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | cayenne
# Processing Record 2 of Set 2 | narsaq
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | tanout
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | gazanjyk
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | marystown
# Processing Record 9 of Set 2 | kalemie
# Processing Record 10 of Set 2 | benjamin aceval
# Processing Record 11 of Set 2 | lukulu
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | kilrush
# Processing Record 14 of Set 2 | lethem
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skip
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | dunedin
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | vaitupu
# City not found. Skip
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skip
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | rincon
# Processing Record 25 of Set 2 | pacific grove
# Processing Record 26 of Set 2 | labuhan
# Processing Record 27 of Set 2 | batsfjord
# Processing Record 28 of Set 2 | bursol
# City not found. Skip
# Processing Record 29 of Set 2 | samalaeulu
# City not found. Skip
# Processing Record 30 of Set 2 | sumbawa
# City not found. Skip
# Processing Record 31 of Set 2 | kapiri mposhi
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | taltal
# Processing Record 34 of Set 2 | eunice
# Processing Record 35 of Set 2 | portobelo
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | canberra
# Processing Record 38 of Set 2 | guerrero negro
# Processing Record 39 of Set 2 | nouadhibou
# Processing Record 40 of Set 2 | kangaba
# Processing Record 41 of Set 2 | dandong
# Processing Record 42 of Set 2 | okhotsk
# Processing Record 43 of Set 2 | dikson
# Processing Record 44 of Set 2 | port moresby
# Processing Record 45 of Set 2 | saint george
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | hobyo
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | benicarlo
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | erzin
# Processing Record 4 of Set 3 | carauari
# Processing Record 5 of Set 3 | biltine
# Processing Record 6 of Set 3 | seoul
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | martapura
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | hohhot
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | lufilufi
# Processing Record 17 of Set 3 | severo-yeniseyskiy
# Processing Record 18 of Set 3 | praia
# Processing Record 19 of Set 3 | vao
# Processing Record 20 of Set 3 | katsuura
# Processing Record 21 of Set 3 | hobart
# Processing Record 22 of Set 3 | tumannyy
# City not found. Skip
# Processing Record 23 of Set 3 | khatanga
# Processing Record 24 of Set 3 | namibe
# Processing Record 25 of Set 3 | rawson
# Processing Record 26 of Set 3 | christchurch
# Processing Record 27 of Set 3 | walvis bay
# Processing Record 28 of Set 3 | los llanos de aridane
# Processing Record 29 of Set 3 | dongsheng
# Processing Record 30 of Set 3 | altamira
# Processing Record 31 of Set 3 | ponta do sol
# Processing Record 32 of Set 3 | pemangkat
# Processing Record 33 of Set 3 | buraydah
# Processing Record 34 of Set 3 | port macquarie
# Processing Record 35 of Set 3 | san quintin
# Processing Record 36 of Set 3 | sibay
# Processing Record 37 of Set 3 | aitape
# Processing Record 38 of Set 3 | coihaique
# Processing Record 39 of Set 3 | nanortalik
# Processing Record 40 of Set 3 | areosa
# Processing Record 41 of Set 3 | minab
# Processing Record 42 of Set 3 | kirakira
# Processing Record 43 of Set 3 | menongue
# Processing Record 44 of Set 3 | cape town
# Processing Record 45 of Set 3 | george
# Processing Record 46 of Set 3 | mitu
# Processing Record 47 of Set 3 | iwanai
# Processing Record 48 of Set 3 | san cristobal
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skip
# Processing Record 50 of Set 3 | panama city
# Processing Record 1 of Set 4 | tombouctou
# Processing Record 2 of Set 4 | sinnamary
# Processing Record 3 of Set 4 | moyale
# Processing Record 4 of Set 4 | kruisfontein
# Processing Record 5 of Set 4 | sovetskiy
# Processing Record 6 of Set 4 | nizhneyansk
# City not found. Skip
# Processing Record 7 of Set 4 | caravelas
# Processing Record 8 of Set 4 | jucuaran
# Processing Record 9 of Set 4 | meiktila
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | cidreira
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | porto novo
# Processing Record 15 of Set 4 | upernavik
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | necochea
# Processing Record 19 of Set 4 | awjilah
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | nuuk
# Processing Record 22 of Set 4 | ulcinj
# Processing Record 23 of Set 4 | kalmunai
# Processing Record 24 of Set 4 | kavaratti
# Processing Record 25 of Set 4 | grindavik
# Processing Record 26 of Set 4 | vung tau
# Processing Record 27 of Set 4 | antofagasta
# Processing Record 28 of Set 4 | laguna
# Processing Record 29 of Set 4 | hamilton
# Processing Record 30 of Set 4 | alamos
# Processing Record 31 of Set 4 | poum
# Processing Record 32 of Set 4 | santa vitoria do palmar
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skip
# Processing Record 34 of Set 4 | portland
# Processing Record 35 of Set 4 | sobolevo
# Processing Record 36 of Set 4 | lishui
# Processing Record 37 of Set 4 | susuman
# Processing Record 38 of Set 4 | lavrentiya
# Processing Record 39 of Set 4 | acari
# Processing Record 40 of Set 4 | hofn
# Processing Record 41 of Set 4 | san jose
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | misratah
# Processing Record 44 of Set 4 | havre-saint-pierre
# Processing Record 45 of Set 4 | loiza
# Processing Record 46 of Set 4 | lujiang
# Processing Record 47 of Set 4 | nizhneangarsk
# Processing Record 48 of Set 4 | marawi
# Processing Record 49 of Set 4 | mecca
# Processing Record 50 of Set 4 | arlit
# Processing Record 1 of Set 5 | tobe
# Processing Record 2 of Set 5 | mbigou
# Processing Record 3 of Set 5 | singaparna
# Processing Record 4 of Set 5 | port hedland
# Processing Record 5 of Set 5 | sharjah
# Processing Record 6 of Set 5 | saint anthony
# Processing Record 7 of Set 5 | amapa
# Processing Record 8 of Set 5 | naze
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skip
# Processing Record 10 of Set 5 | muros
# Processing Record 11 of Set 5 | aksarka
# Processing Record 12 of Set 5 | kieta
# Processing Record 13 of Set 5 | missoula
# Processing Record 14 of Set 5 | east wenatchee
# Processing Record 15 of Set 5 | nantucket
# Processing Record 16 of Set 5 | tansen
# Processing Record 17 of Set 5 | prince rupert
# Processing Record 18 of Set 5 | zhigansk
# Processing Record 19 of Set 5 | el tigre
# Processing Record 20 of Set 5 | fortuna
# Processing Record 21 of Set 5 | longyearbyen
# Processing Record 22 of Set 5 | pimentel
# Processing Record 23 of Set 5 | arroyos y esteros
# Processing Record 24 of Set 5 | roma
# Processing Record 25 of Set 5 | torit
# Processing Record 26 of Set 5 | buala
# Processing Record 27 of Set 5 | tuatapere
# Processing Record 28 of Set 5 | leh
# Processing Record 29 of Set 5 | clyde river
# Processing Record 30 of Set 5 | leua
# Processing Record 31 of Set 5 | palabuhanratu
# City not found. Skip
# Processing Record 32 of Set 5 | vanavara
# Processing Record 33 of Set 5 | bengkulu
# Processing Record 34 of Set 5 | ilulissat
# Processing Record 35 of Set 5 | arua
# Processing Record 36 of Set 5 | esperance
# Processing Record 37 of Set 5 | kudahuvadhoo
# Processing Record 38 of Set 5 | salalah
# Processing Record 39 of Set 5 | barentsburg
# City not found. Skip
# Processing Record 40 of Set 5 | kovdor
# Processing Record 41 of Set 5 | governador valadares
# Processing Record 42 of Set 5 | aanekoski
# Processing Record 43 of Set 5 | kabo
# Processing Record 44 of Set 5 | ancud
# Processing Record 45 of Set 5 | shingu
# Processing Record 46 of Set 5 | attawapiskat
# City not found. Skip
# Processing Record 47 of Set 5 | maromitsa
# Processing Record 48 of Set 5 | segovia
# Processing Record 49 of Set 5 | morden
# Processing Record 50 of Set 5 | lake city
# Processing Record 1 of Set 6 | ilhabela
# Processing Record 2 of Set 6 | adre
# Processing Record 3 of Set 6 | wollongong
# Processing Record 4 of Set 6 | inderborskiy
# City not found. Skip
# Processing Record 5 of Set 6 | talnakh
# Processing Record 6 of Set 6 | zenzeli
# Processing Record 7 of Set 6 | berbera
# Processing Record 8 of Set 6 | berlevag
# Processing Record 9 of Set 6 | vestmanna
# Processing Record 10 of Set 6 | umm durman
# City not found. Skip
# Processing Record 11 of Set 6 | malanje
# Processing Record 12 of Set 6 | havoysund
# Processing Record 13 of Set 6 | mnogovershinnyy
# Processing Record 14 of Set 6 | eirunepe
# Processing Record 15 of Set 6 | west bay
# Processing Record 16 of Set 6 | gandajika
# Processing Record 17 of Set 6 | tiarei
# Processing Record 18 of Set 6 | henties bay
# Processing Record 19 of Set 6 | pangnirtung
# Processing Record 20 of Set 6 | foumban
# Processing Record 21 of Set 6 | rundu
# Processing Record 22 of Set 6 | deh rawud
# City not found. Skip
# Processing Record 23 of Set 6 | monrovia
# Processing Record 24 of Set 6 | chokurdakh
# Processing Record 25 of Set 6 | sao felix do xingu
# Processing Record 26 of Set 6 | banjar
# Processing Record 27 of Set 6 | cherskiy
# Processing Record 28 of Set 6 | aksu
# Processing Record 29 of Set 6 | mrirt
# City not found. Skip
# Processing Record 30 of Set 6 | bosaso
# Processing Record 31 of Set 6 | aripuana
# Processing Record 32 of Set 6 | mae hong son
# Processing Record 33 of Set 6 | vila velha
# Processing Record 34 of Set 6 | ewa beach
# Processing Record 35 of Set 6 | haines junction
# Processing Record 36 of Set 6 | bonavista
# Processing Record 37 of Set 6 | karachi
# Processing Record 38 of Set 6 | torbay
# Processing Record 39 of Set 6 | kintinku
# Processing Record 40 of Set 6 | chimbote
# Processing Record 41 of Set 6 | sabang
# Processing Record 42 of Set 6 | zheshart
# Processing Record 43 of Set 6 | bairiki
# Processing Record 44 of Set 6 | borba
# Processing Record 45 of Set 6 | yumen
# Processing Record 46 of Set 6 | kumbo
# Processing Record 47 of Set 6 | camenca
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | tabuk
# Processing Record 50 of Set 6 | richards bay
# Processing Record 1 of Set 7 | ust-tsilma
# Processing Record 2 of Set 7 | qingdao
# Processing Record 3 of Set 7 | kuytun
# Processing Record 4 of Set 7 | lagoa
# Processing Record 5 of Set 7 | hong gai
# Processing Record 6 of Set 7 | kosh-agach
# Processing Record 7 of Set 7 | krasnoborsk
# Processing Record 8 of Set 7 | kurmanayevka
# Processing Record 9 of Set 7 | tazmalt
# Processing Record 10 of Set 7 | northam
# Processing Record 11 of Set 7 | quatre cocos
# Processing Record 12 of Set 7 | flinders
# Processing Record 13 of Set 7 | cruzeiro do sul
# Processing Record 14 of Set 7 | kununurra
# Processing Record 15 of Set 7 | ostersund
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | azimur
# City not found. Skip
# Processing Record 18 of Set 7 | mananjary
# Processing Record 19 of Set 7 | goiania
# Processing Record 20 of Set 7 | lasa
# Processing Record 21 of Set 7 | yellowknife
# Processing Record 22 of Set 7 | belushya guba
# City not found. Skip
# Processing Record 23 of Set 7 | kerema
# Processing Record 24 of Set 7 | gari
# Processing Record 25 of Set 7 | ca mau
# Processing Record 26 of Set 7 | norman wells
# Processing Record 27 of Set 7 | camacha
# Processing Record 28 of Set 7 | jumla
# Processing Record 29 of Set 7 | kamenskoye
# City not found. Skip
# Processing Record 30 of Set 7 | ostrovnoy
# Processing Record 31 of Set 7 | sao filipe
# Processing Record 32 of Set 7 | nortelandia
# Processing Record 33 of Set 7 | ulaangom
# Processing Record 34 of Set 7 | finschhafen
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | peniche
# Processing Record 37 of Set 7 | rancho palos verdes
# Processing Record 38 of Set 7 | sur
# Processing Record 39 of Set 7 | mapiripan
# Processing Record 40 of Set 7 | thinadhoo
# Processing Record 41 of Set 7 | malwan
# City not found. Skip
# Processing Record 42 of Set 7 | ternate
# Processing Record 43 of Set 7 | geraldton
# Processing Record 44 of Set 7 | kastamonu
# Processing Record 45 of Set 7 | saquisili
# Processing Record 46 of Set 7 | alice springs
# Processing Record 47 of Set 7 | maldonado
# Processing Record 48 of Set 7 | klaksvik
# Processing Record 49 of Set 7 | tyukhtet
# Processing Record 50 of Set 7 | tripoli
# Processing Record 1 of Set 8 | kontagora
# Processing Record 2 of Set 8 | elizabeth city
# Processing Record 3 of Set 8 | pasni
# Processing Record 4 of Set 8 | codrington
# Processing Record 5 of Set 8 | yarim
# Processing Record 6 of Set 8 | port keats
# Processing Record 7 of Set 8 | potsdam
# Processing Record 8 of Set 8 | marinette
# Processing Record 9 of Set 8 | tabialan
# City not found. Skip
# Processing Record 10 of Set 8 | castro
# Processing Record 11 of Set 8 | jimo
# Processing Record 12 of Set 8 | nguiu
# City not found. Skip
# Processing Record 13 of Set 8 | east moline
# Processing Record 14 of Set 8 | asau
# Processing Record 15 of Set 8 | ossora
# Processing Record 16 of Set 8 | plettenberg bay
# Processing Record 17 of Set 8 | acapulco
# Processing Record 18 of Set 8 | gweta
# Processing Record 19 of Set 8 | bambanglipuro
# Processing Record 20 of Set 8 | puerto plata
# Processing Record 21 of Set 8 | cockburn town
# Processing Record 22 of Set 8 | bubaque
# Processing Record 23 of Set 8 | mercedes
# Processing Record 24 of Set 8 | gola gokarannath
# Processing Record 25 of Set 8 | mandera
# Processing Record 26 of Set 8 | hovelhof
# Processing Record 27 of Set 8 | goiatuba
# Processing Record 28 of Set 8 | tsabong
# Processing Record 29 of Set 8 | abha
# Processing Record 30 of Set 8 | eureka
# Processing Record 31 of Set 8 | dien bien
# City not found. Skip
# Processing Record 32 of Set 8 | paita
# Processing Record 33 of Set 8 | ilo
# Processing Record 34 of Set 8 | umzimvubu
# City not found. Skip
# Processing Record 35 of Set 8 | verkhnyaya inta
# Processing Record 36 of Set 8 | dadri
# Processing Record 37 of Set 8 | avera
# Processing Record 38 of Set 8 | bavly
# Processing Record 39 of Set 8 | taoudenni
# Processing Record 40 of Set 8 | dickinson
# Processing Record 41 of Set 8 | roald
# Processing Record 42 of Set 8 | leninskoye
# Processing Record 43 of Set 8 | derzhavinsk
# Processing Record 44 of Set 8 | verkhnyaya toyma
# Processing Record 45 of Set 8 | hengshui
# Processing Record 46 of Set 8 | sal rei
# Processing Record 47 of Set 8 | bereznik
# Processing Record 48 of Set 8 | altay
# Processing Record 49 of Set 8 | vanimo
# Processing Record 50 of Set 8 | las cruces
# Processing Record 1 of Set 9 | tiksi
# Processing Record 2 of Set 9 | sakakah
# Processing Record 3 of Set 9 | thompson
# Processing Record 4 of Set 9 | roseburg
# Processing Record 5 of Set 9 | cornatelu
# Processing Record 6 of Set 9 | mehamn
# Processing Record 7 of Set 9 | codajas
# Processing Record 8 of Set 9 | stawell
# Processing Record 9 of Set 9 | padang
# Processing Record 10 of Set 9 | eucaliptus
# Processing Record 11 of Set 9 | kwekwe
# Processing Record 12 of Set 9 | causapscal
# Processing Record 13 of Set 9 | piuma
# Processing Record 14 of Set 9 | kahului
# Processing Record 15 of Set 9 | yulara
# Processing Record 16 of Set 9 | shakawe
# Processing Record 17 of Set 9 | dhangadhi
# Processing Record 18 of Set 9 | dingle
# Processing Record 19 of Set 9 | gorele
# Processing Record 20 of Set 9 | mariara
# Processing Record 21 of Set 9 | kampot
# Processing Record 22 of Set 9 | fare
# Processing Record 23 of Set 9 | yabrud
# Processing Record 24 of Set 9 | dapdapan
# Processing Record 25 of Set 9 | smolenka
# Processing Record 26 of Set 9 | saryshagan
# City not found. Skip
# Processing Record 27 of Set 9 | mafinga
# Processing Record 28 of Set 9 | pionerskiy
# Processing Record 29 of Set 9 | ornskoldsvik
# Processing Record 30 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 9 | provideniya
# Processing Record 32 of Set 9 | dubenskiy
# City not found. Skip
# Processing Record 33 of Set 9 | rocha
# Processing Record 34 of Set 9 | eyl
# Processing Record 35 of Set 9 | malpe
# Processing Record 36 of Set 9 | serebryansk
# Processing Record 37 of Set 9 | touros
# Processing Record 38 of Set 9 | mount isa
# Processing Record 39 of Set 9 | ouesso
# Processing Record 40 of Set 9 | marrakesh
# Processing Record 41 of Set 9 | afmadu
# City not found. Skip
# Processing Record 42 of Set 9 | helong
# Processing Record 43 of Set 9 | katherine
# Processing Record 44 of Set 9 | broken hill
# Processing Record 45 of Set 9 | pingzhuang
# Processing Record 46 of Set 9 | alamogordo
# Processing Record 47 of Set 9 | rock sound
# Processing Record 48 of Set 9 | kibala
# Processing Record 49 of Set 9 | mackenzie
# Processing Record 50 of Set 9 | gboko
# Processing Record 1 of Set 10 | gao
# Processing Record 2 of Set 10 | vostok
# Processing Record 3 of Set 10 | tabulbah
# City not found. Skip
# Processing Record 4 of Set 10 | tessalit
# Processing Record 5 of Set 10 | burica
# City not found. Skip
# Processing Record 6 of Set 10 | kologriv
# Processing Record 7 of Set 10 | lubao
# Processing Record 8 of Set 10 | pagman
# City not found. Skip
# Processing Record 9 of Set 10 | dabola
# Processing Record 10 of Set 10 | glenwood springs
# Processing Record 11 of Set 10 | pisco
# Processing Record 12 of Set 10 | kyabe
# Processing Record 13 of Set 10 | xining
# Processing Record 14 of Set 10 | turayf
# Processing Record 15 of Set 10 | segou
# Processing Record 16 of Set 10 | oksfjord
# Processing Record 17 of Set 10 | saint-joseph
# Processing Record 18 of Set 10 | half moon bay
# Processing Record 19 of Set 10 | turmero
# Processing Record 20 of Set 10 | lucea
# Processing Record 21 of Set 10 | camopi
# Processing Record 22 of Set 10 | bathsheba
# Processing Record 23 of Set 10 | ukiah
# Processing Record 24 of Set 10 | las margaritas
# Processing Record 25 of Set 10 | haapiti
# Processing Record 26 of Set 10 | mweka
# Processing Record 27 of Set 10 | ihosy
# Processing Record 28 of Set 10 | fairbanks
# Processing Record 29 of Set 10 | araure
# Processing Record 30 of Set 10 | chikoy
# City not found. Skip
# Processing Record 31 of Set 10 | kalmar
# Processing Record 32 of Set 10 | magadan
# Processing Record 33 of Set 10 | samusu
# City not found. Skip
# Processing Record 34 of Set 10 | rungata
# City not found. Skip
# Processing Record 35 of Set 10 | champerico
# Processing Record 36 of Set 10 | chupa
# Processing Record 37 of Set 10 | san carlos de bariloche
# Processing Record 38 of Set 10 | prince albert
# Processing Record 39 of Set 10 | leshukonskoye
# Processing Record 40 of Set 10 | tucuma
# Processing Record 41 of Set 10 | alekseyevsk
# Processing Record 42 of Set 10 | meadow lake
# Processing Record 43 of Set 10 | igarka
# Processing Record 44 of Set 10 | kapoeta
# Processing Record 45 of Set 10 | luan
# Processing Record 46 of Set 10 | khonuu
# City not found. Skip
# Processing Record 47 of Set 10 | carutapera
# Processing Record 48 of Set 10 | ozernovskiy
# Processing Record 49 of Set 10 | challans
# Processing Record 50 of Set 10 | minsk
# Processing Record 1 of Set 11 | presidencia roque saenz pena
# Processing Record 2 of Set 11 | mariana
# Processing Record 3 of Set 11 | opuwo
# Processing Record 4 of Set 11 | soe
# Processing Record 5 of Set 11 | leningradskiy
# Processing Record 6 of Set 11 | lorengau
# Processing Record 7 of Set 11 | jinchengjiang
# City not found. Skip
# Processing Record 8 of Set 11 | nome
# Processing Record 9 of Set 11 | zhurivka
# Processing Record 10 of Set 11 | ahuimanu
# Processing Record 11 of Set 11 | la palma
# Processing Record 12 of Set 11 | comodoro rivadavia
# Processing Record 13 of Set 11 | faya
# Processing Record 14 of Set 11 | kyshtovka
# Processing Record 15 of Set 11 | kez
# Processing Record 16 of Set 11 | santa cruz
# Processing Record 17 of Set 11 | bokspits
# City not found. Skip
# Processing Record 18 of Set 11 | hannibal
# Processing Record 19 of Set 11 | egvekinot
# Processing Record 20 of Set 11 | san patricio
# Processing Record 21 of Set 11 | torremolinos
# Processing Record 22 of Set 11 | hayden
# Processing Record 23 of Set 11 | auki
# Processing Record 24 of Set 11 | aklavik
# Processing Record 25 of Set 11 | aktau
# Processing Record 26 of Set 11 | aflu
# City not found. Skip
# Processing Record 27 of Set 11 | uige
# Processing Record 28 of Set 11 | fukue
# Processing Record 29 of Set 11 | ixtapa
# Processing Record 30 of Set 11 | anadyr
# Processing Record 31 of Set 11 | chapais
# Processing Record 32 of Set 11 | sidi ali
# Processing Record 33 of Set 11 | alofi
# Processing Record 34 of Set 11 | arenapolis
# Processing Record 35 of Set 11 | thames
# Processing Record 36 of Set 11 | ilheus
# Processing Record 37 of Set 11 | xichang
# Processing Record 38 of Set 11 | ballangen
# Processing Record 39 of Set 11 | sorland
# Processing Record 40 of Set 11 | tabou
# Processing Record 41 of Set 11 | nador
# Processing Record 42 of Set 11 | port-gentil
# Processing Record 43 of Set 11 | pingxiang
# Processing Record 44 of Set 11 | chara
# Processing Record 45 of Set 11 | madaoua
# Processing Record 46 of Set 11 | kalabo
# Processing Record 47 of Set 11 | farah
# Processing Record 48 of Set 11 | san juan
# Processing Record 49 of Set 11 | saint-pierre
# Processing Record 50 of Set 11 | manokwari
# Processing Record 1 of Set 12 | burns lake
# Processing Record 2 of Set 12 | komsomolskiy
# Processing Record 3 of Set 12 | rodino
# Processing Record 4 of Set 12 | woodward
# Processing Record 5 of Set 12 | ust-ishim
# Processing Record 6 of Set 12 | deputatskiy
# Processing Record 7 of Set 12 | antanifotsy
# Processing Record 8 of Set 12 | te anau
# Processing Record 9 of Set 12 | urumqi
# Processing Record 10 of Set 12 | douglas
# Processing Record 11 of Set 12 | mpika
# Processing Record 12 of Set 12 | riverton
# Processing Record 13 of Set 12 | upata
# Processing Record 14 of Set 12 | margate
# Processing Record 15 of Set 12 | lazaro cardenas
# Processing Record 16 of Set 12 | port hardy
# Processing Record 17 of Set 12 | raudeberg
# Processing Record 18 of Set 12 | tutoia
# Processing Record 19 of Set 12 | along
# Processing Record 20 of Set 12 | saint-augustin
# Processing Record 21 of Set 12 | datong
# Processing Record 22 of Set 12 | mogadishu
# Processing Record 23 of Set 12 | brae
# Processing Record 24 of Set 12 | harper
# Processing Record 25 of Set 12 | bur gabo
# City not found. Skip
# Processing Record 26 of Set 12 | onega
# Processing Record 27 of Set 12 | ust-nera
# Processing Record 28 of Set 12 | mananara
# Processing Record 29 of Set 12 | ngunguru
# Processing Record 30 of Set 12 | caala
# Processing Record 31 of Set 12 | grenaa
# Processing Record 32 of Set 12 | dzemul
# Processing Record 33 of Set 12 | kainantu
# Processing Record 34 of Set 12 | shenzhen
# Processing Record 35 of Set 12 | great falls
# Processing Record 36 of Set 12 | nanakuli
# Processing Record 37 of Set 12 | petropavlovka
# Processing Record 38 of Set 12 | shache
# Processing Record 39 of Set 12 | marhaura
# Processing Record 40 of Set 12 | jiexiu
# Processing Record 41 of Set 12 | beloha
# Processing Record 42 of Set 12 | changping
# Processing Record 43 of Set 12 | san luis rio colorado
# Processing Record 44 of Set 12 | quesnel
# Processing Record 45 of Set 12 | echirolles
# Processing Record 46 of Set 12 | melong
# Processing Record 47 of Set 12 | maubin
# Processing Record 48 of Set 12 | havelock
# Processing Record 49 of Set 12 | grand junction
# Processing Record 50 of Set 12 | karkaralinsk
# City not found. Skip
# Processing Record 1 of Set 13 | bima
# Processing Record 2 of Set 13 | mizan teferi
# Processing Record 3 of Set 13 | toliary
# City not found. Skip
# Processing Record 4 of Set 13 | hualmay
# Processing Record 5 of Set 13 | udachnyy
# Processing Record 6 of Set 13 | sosnovskiy
# City not found. Skip
# Processing Record 7 of Set 13 | shenkursk
# Processing Record 8 of Set 13 | umuarama
# Processing Record 9 of Set 13 | sapernoye
# Processing Record 10 of Set 13 | jerantut
# Processing Record 11 of Set 13 | mushie
# Processing Record 12 of Set 13 | soure
# Processing Record 13 of Set 13 | la roda
# Processing Record 14 of Set 13 | husavik
# Processing Record 15 of Set 13 | konevo
# Processing Record 16 of Set 13 | lashio
# Processing Record 17 of Set 13 | tamandare
# Processing Record 18 of Set 13 | gravdal
# Processing Record 19 of Set 13 | bardiyah
# Processing Record 20 of Set 13 | dong hoi
# Processing Record 21 of Set 13 | el faiyum
# City not found. Skip
# Processing Record 22 of Set 13 | healesville
# Processing Record 23 of Set 13 | nemuro
# Processing Record 24 of Set 13 | kenai
# Processing Record 25 of Set 13 | east brainerd
# Processing Record 26 of Set 13 | vila
# Processing Record 27 of Set 13 | andenes
# Processing Record 28 of Set 13 | sao joao da barra
# Processing Record 29 of Set 13 | abnub
# Processing Record 30 of Set 13 | tukrah
# Processing Record 31 of Set 13 | sistranda
# Processing Record 32 of Set 13 | dicabisagan
# Processing Record 33 of Set 13 | belyy yar
# Processing Record 34 of Set 13 | narasannapeta
# Processing Record 35 of Set 13 | broome
# Processing Record 36 of Set 13 | murud
# Processing Record 37 of Set 13 | cairns
# Processing Record 38 of Set 13 | tuy hoa
# Processing Record 39 of Set 13 | nishihara
# Processing Record 40 of Set 13 | kiruna
# Processing Record 41 of Set 13 | guanagazapa
# Processing Record 42 of Set 13 | kiunga
# Processing Record 43 of Set 13 | ust-maya
# Processing Record 44 of Set 13 | souillac
# Processing Record 45 of Set 13 | tiruchchendur
# Processing Record 46 of Set 13 | aswan
# Processing Record 47 of Set 13 | mullaitivu
# City not found. Skip
# Processing Record 48 of Set 13 | haimen
# Processing Record 49 of Set 13 | hay river
# Processing Record 50 of Set 13 | sento se
# City not found. Skip
# Processing Record 1 of Set 14 | jabiru
# City not found. Skip
# Processing Record 2 of Set 14 | tatarbunary
# Processing Record 3 of Set 14 | agirish
# Processing Record 4 of Set 14 | allada
# Processing Record 5 of Set 14 | balabac
# Processing Record 6 of Set 14 | marsh harbour
# Processing Record 7 of Set 14 | cicero dantas
# Processing Record 8 of Set 14 | qaqortoq
# Processing Record 9 of Set 14 | stokmarknes
# Processing Record 10 of Set 14 | cap malheureux
# Processing Record 11 of Set 14 | wulanhaote
# City not found. Skip
# Processing Record 12 of Set 14 | kassala
# Processing Record 13 of Set 14 | kaeo
# Processing Record 14 of Set 14 | ciudad bolivar
# Processing Record 15 of Set 14 | kazachinskoye
# Processing Record 16 of Set 14 | dhidhdhoo
# Processing Record 17 of Set 14 | naftah
# City not found. Skip
# Processing Record 18 of Set 14 | behbahan
# Processing Record 19 of Set 14 | skagastrond
# City not found. Skip
# Processing Record 20 of Set 14 | parauna
# Processing Record 21 of Set 14 | shubarkuduk
# Processing Record 22 of Set 14 | xingcheng
# Processing Record 23 of Set 14 | dawei
# Processing Record 24 of Set 14 | miandrivazo
# Processing Record 25 of Set 14 | saleaula
# City not found. Skip
# Processing Record 26 of Set 14 | aleksandrov gay
# Processing Record 27 of Set 14 | payson
# Processing Record 28 of Set 14 | vestmannaeyjar
# Processing Record 29 of Set 14 | agadez
# Processing Record 30 of Set 14 | mareeba
# Processing Record 31 of Set 14 | kargasok
# Processing Record 32 of Set 14 | corabia
# Processing Record 33 of Set 14 | lata
# Processing Record 34 of Set 14 | panzhihua
# Processing Record 35 of Set 14 | tura
# Processing Record 36 of Set 14 | masuguru
# Processing Record 37 of Set 14 | morant bay
# Processing Record 38 of Set 14 | orlik
# Processing Record 39 of Set 14 | gat
# Processing Record 40 of Set 14 | parsabad
# Processing Record 41 of Set 14 | igrim
# Processing Record 42 of Set 14 | sataua
# City not found. Skip
# Processing Record 43 of Set 14 | muravlenko
# Processing Record 44 of Set 14 | mollendo
# Processing Record 45 of Set 14 | coahuayana
# Processing Record 46 of Set 14 | tamala
# Processing Record 47 of Set 14 | payo
# Processing Record 48 of Set 14 | liberal
# Processing Record 49 of Set 14 | college
# Processing Record 50 of Set 14 | ulladulla
# Processing Record 1 of Set 15 | krasnoyarka
# Processing Record 2 of Set 15 | abu kamal
# Processing Record 3 of Set 15 | santarem
# Processing Record 4 of Set 15 | mutis
# Processing Record 5 of Set 15 | matay
# Processing Record 6 of Set 15 | mao
# Processing Record 7 of Set 15 | sao jose da coroa grande
# Processing Record 8 of Set 15 | urucui
# Processing Record 9 of Set 15 | danjiangkou
# Processing Record 10 of Set 15 | araouane
# Processing Record 11 of Set 15 | quetzaltepec
# City not found. Skip
# Processing Record 12 of Set 15 | port hawkesbury
# Processing Record 13 of Set 15 | itarema
# Processing Record 14 of Set 15 | brumunddal
# Processing Record 15 of Set 15 | barbar
# City not found. Skip
# Processing Record 16 of Set 15 | ejura
# Processing Record 17 of Set 15 | adilabad
# Processing Record 18 of Set 15 | nowa sol
# Processing Record 19 of Set 15 | falealupo
# City not found. Skip
# Processing Record 20 of Set 15 | macapa
# Processing Record 21 of Set 15 | bobonong
# City not found. Skip
# Processing Record 22 of Set 15 | atlantic city
# Processing Record 23 of Set 15 | bolungarvik
# City not found. Skip
# Processing Record 24 of Set 15 | prudentopolis
# Processing Record 25 of Set 15 | plouzane
# Processing Record 26 of Set 15 | grants pass
# Processing Record 27 of Set 15 | kifri
# Processing Record 28 of Set 15 | dukat
# Processing Record 29 of Set 15 | chitral
# Processing Record 30 of Set 15 | cherrapunji
# Processing Record 31 of Set 15 | luang prabang
# Processing Record 32 of Set 15 | mitsamiouli
# Processing Record 33 of Set 15 | namatanai
# Processing Record 34 of Set 15 | twentynine palms
# Processing Record 35 of Set 15 | mora
# Processing Record 36 of Set 15 | tabiauea
# City not found. Skip
# Processing Record 37 of Set 15 | hit
# Processing Record 38 of Set 15 | ishigaki
# Processing Record 39 of Set 15 | darnah
# Processing Record 40 of Set 15 | eldikan
# City not found. Skip
# Processing Record 41 of Set 15 | bay roberts
# Processing Record 42 of Set 15 | yar-sale
# Processing Record 43 of Set 15 | tiznit
# Processing Record 44 of Set 15 | poya
# Processing Record 45 of Set 15 | ryotsu
# Processing Record 46 of Set 15 | nioki
# Processing Record 47 of Set 15 | alyth
# Processing Record 48 of Set 15 | ust-kut
# Processing Record 49 of Set 15 | axim
# Processing Record 50 of Set 15 | luorong
# Processing Record 1 of Set 16 | jalu
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 689

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         mataura      NZ -46.1927  168.8643     41.49        98          35
# 1     new norfolk      AU -42.7826  147.0587     58.50        63          52
# 2      butaritari      KI   3.0707  172.7902     82.76        68          60
# 3  saint-philippe      RE -21.3585   55.7679     72.99        84          51
# 4       orzhytsya      UA  49.7918   32.7012     75.83        60          79
# 5            cody      US  44.5263 -109.0565     80.91        18           1
# 6          jasper      US  37.2001  -94.3502     92.44        64          20
# 7          barrow      US  71.2906 -156.7887     37.42        81          90
# 8         iqaluit      CA  63.7506  -68.5145     47.93        71          90
# 9            juba      SS   4.8517   31.5825     73.44        85          76
#
#    Wind Speed Current Description
# 0        2.53    scattered clouds
# 1        3.00       moderate rain
# 2       13.15       broken clouds
# 3        8.57       broken clouds
# 4        6.55       broken clouds
# 5       13.80           clear sky
# 6        3.00          few clouds
# 7        8.05     overcast clouds
# 8        9.22     overcast clouds
# 9        4.52          light rain

# %%
# Create the output file (CSV).
city_data_df.to_csv('WeatherPy_Database.csv')
city_data_df.to_csv("dframe.csv", sep=',')
